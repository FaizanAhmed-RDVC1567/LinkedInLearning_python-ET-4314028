# %% [markdown]
# # Title
# ## Smaller Title

# %% [markdown]
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %%
print('Doing some data science!')
# Out:
# Doing some data science!

# %%
print(1 + 1)
# Out:
# 2

# %% [markdown]
# # Some Personal code
# ## notes for markdown

# %% [markdown]
# Markdown is cool and very helpful, it's quite ubiquitous in the developer world as it used for documentation and so much more.
# There's lots of information that can be displayed in Markdown files such as titles, text, mathematical equations, nested lists and regular lists, embedded code samples and more.

# %%
print("Equation example below!")
# Out:
# Equation example below!

# %% [markdown]
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %% [markdown]
# The above uses LaTex equation styles in Jupyter notebooks, courtesy of MathJax.
